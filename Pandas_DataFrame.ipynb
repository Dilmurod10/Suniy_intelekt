# %% [markdown]
# <a href="https://colab.research.google.com/github/Dilmurod10/Suniy_intelekt/blob/main/Pandas_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data={
    "yil":[2020,2021,2022,2023,2024],
    'fanlar':[10,12,9,7,0],
    'talab':[5,5,4,2,0]
}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#     yil  fanlar  talab
# 0  2020      10      5
# 1  2021      12      5
# 2  2022       9      4
# 3  2023       7      2
# 4  2024       0      0

# %%
df.head()
# Out:
#     yil  fanlar  talab
# 0  2020      10      5
# 1  2021      12      5
# 2  2022       9      4
# 3  2023       7      2
# 4  2024       0      0

# %%
df.head(2)
# Out:
#     yil  fanlar  talab
# 0  2020      10      5
# 1  2021      12      5

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.size
# Out:
# 15

# %%
df.shape
# Out:
# (5, 3)

# %%
df=pd.DataFrame(data,columns=['talab','yil','fanlar','talaba soni'])

# %%
df
# Out:
#    talab   yil  fanlar talaba soni
# 0      5  2020      10         NaN
# 1      5  2021      12         NaN
# 2      4  2022       9         NaN
# 3      2  2023       7         NaN
# 4      0  2024       0         NaN

# %%
df1=df.yil

# %%
df1
# Out:
# 0    2020
# 1    2021
# 2    2022
# 3    2023
# 4    2024
# Name: yil, dtype: int64

# %%
df=pd.DataFrame(data,columns=['talab','yil','fanlar','talaba soni'],index=[1,2,3,4,5])

# %%
df
# Out:
#    talab   yil  fanlar talaba soni
# 1      5  2020      10         NaN
# 2      5  2021      12         NaN
# 3      4  2022       9         NaN
# 4      2  2023       7         NaN
# 5      0  2024       0         NaN

# %%
df['talaba soni']=25

# %%
df
# Out:
#    talab   yil  fanlar  talaba soni
# 1      5  2020      10           25
# 2      5  2021      12           25
# 3      4  2022       9           25
# 4      2  2023       7           25
# 5      0  2024       0           25

# %%
val=pd.Series([30,29],index=[1,2])

# %%
df['talaba soni']=val
df
# Out:
#    talab   yil  fanlar  talaba soni
# 1      5  2020      10         30.0
# 2      5  2021      12         29.0
# 3      4  2022       9          NaN
# 4      2  2023       7          NaN
# 5      0  2024       0          NaN

# %%
df['25+']=df["talaba soni"]>25
df
# Out:
#    talab   yil  fanlar  talaba soni    25+
# 1      5  2020      10         30.0   True
# 2      5  2021      12         29.0   True
# 3      4  2022       9          NaN  False
# 4      2  2023       7          NaN  False
# 5      0  2024       0          NaN  False

# %%
del df['25+']

# %%
df
# Out:
#    talab   yil  fanlar  talaba soni
# 1      5  2020      10         30.0
# 2      5  2021      12         29.0
# 3      4  2022       9          NaN
# 4      2  2023       7          NaN
# 5      0  2024       0          NaN

# %%
data2 = {
    'Uzbekistan':{2021:33.9, 2020:33.5, 2019:32.9, 2018:32.5, 2017:31.9},
    'Kazakhstan':{2021:18.9, 2020:18.7, 2019:18.5, 2018:18.3, 2017:18.1, 2016:17.8}
}

# %%
df3=pd.DataFrame(data2)

# %%
df3
# Out:
#       Uzbekistan  Kazakhstan
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df3.T
# Out:
#             2021  2020  2019  2018  2017  2016
# Uzbekistan  33.9  33.5  32.9  32.5  31.9   NaN
# Kazakhstan  18.9  18.7  18.5  18.3  18.1  17.8

# %%
arr=df3.values

# %%
arr
# Out:
# array([[33.9, 18.9],
#        [33.5, 18.7],
#        [32.9, 18.5],
#        [32.5, 18.3],
#        [31.9, 18.1],
#        [ nan, 17.8]])

# %%
df3.index.name='year'

# %%
df3
# Out:
#       Uzbekistan  Kazakhstan
# year
# 2021        33.9        18.9
# 2020        33.5        18.7
# 2019        32.9        18.5
# 2018        32.5        18.3
# 2017        31.9        18.1
# 2016         NaN        17.8

# %%
df3=pd.DataFrame(data2,index=[2017,2018,2021])
df3
# Out:
#       Uzbekistan  Kazakhstan
# 2017        31.9        18.1
# 2018        32.5        18.3
# 2021        33.9        18.9
